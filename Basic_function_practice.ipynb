# %% [markdown]
# # Practice Questions on Functions

# %% [raw]
#  Q1: Write a function sum_numbers(a, b) that takes two numbers as input and does the following:
# o Prints the sum of the numbers.
# o Returns the sum of the numbers.
# o Call the function and explain the difference between the print and return values.

# %%
def sum_numbers(a, b):
    return a + b

sum_numbers(9, 6)
# Out:
# 15

# %%
def sum_numbers(a, b):
    print("Addition is ", a + b)

sum_numbers(9, 6)
# Out:
# Addition is  15

# %% [markdown]
# # Local and Global Variables

# %%
'''  Q2: Write a program where:
o You define a global variable counter with an initial value of 0.
o Create a function increment() that increments counter by 1 each time it is called and prints its value.
o Call the function three times and observe the output. '''

counter = 0

def increment():
    global counter
    counter += 1
    print(f"Counter value: {counter}")

increment()
increment()
increment()
# Out:
# Counter value: 1
# Counter value: 2
# Counter value: 3

# %%
# Q3: Write a function demo_local() that declares a local variable message = "Hello, Local" and prints it. Outside the function, try to print 
#the same message variable and note the error.
def demo_local():
    message = "Hello, Local"
    print(f"Inside function: {message}")

demo_local()
print(f"Outside function: {message}")
# Out:
# Inside function: Hello, Local
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       5     print(f"Inside function: {message}")
#       7 demo_local()
# ----> 8 print(f"Outside function: {message}")
#
# NameError: name 'message' is not defined

# %%
# Q4: Modify demo_local() from the previous question to access a global variable
# message = "Hello, Global" from within the function.
message = "Hello, Local"

def demo_local():
    global message
    print(f"Inside function: {message}")

demo_local()
print(f"Outside function: {message}")
# Out:
# Inside function: Hello, Local
# Outside function: Hello, Local

# %% [markdown]
# # Writing Docstrings

# %%
'''
 Q5: Write a function greet(name) that takes a name as input and returns a greeting message like "Hello, John!".
o Add a proper docstring describing the purpose of the function, its input parameter, and its return value.
o Use help() to display the docstring. '''

def greet(name):
    """
    Generates a personalized greeting message.
    
    Parameters:
    name (str): The name of the person to greet.

    Returns:
    str: A greeting string in the format "Hello, <name>!".
    """
    return f"Hello, {name}!"

message = greet("John")
print(message)

print("\n--- Displaying Function Documentation ---")
help(greet)
# Out:
# Hello, John!
#
# --- Displaying Function Documentation ---
# Help on function greet in module __main__:
#
# greet(name)
#     Generates a personalized greeting message.
#
#     Parameters:
#     name (str): The name of the person to greet.
#
#     Returns:
#     str: A greeting string in the format "Hello, <name>!".

# %%
'''  Q6: Write a function calculate_area(radius) to compute the area of a circle given its radius.
o Add a docstring explaining the formula used for calculation and the purpose of the function. '''

import math

def calculate_area(radius):
    """
    Calculate the area of a circle.

    Formula:
        Area = π × r²
    where:
        π (pi) is approximately 3.14159
        r is the radius of the circle

    Parameters:
        radius (float): The radius of the circle.

    Returns:
        float: The area of the circle.
    """
    return math.pi * radius ** 2


# Example usage
r = 5
area = calculate_area(r)
print("Area of the circle =", area)
# Out:
# Area of the circle = 78.53981633974483

# %% [markdown]
# # Functions with Return

# %%
#  Q7: Write a function is_even(n) that returns True if a number is even, otherwise returns False. Test the function with multiple inputs.
def is_even(n):
    if n % 2 == 0:
        return True
    else:
        return False

is_even(5)
# Out:
# False

# %%
is_even(6)
# Out:
# True
